# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Modeling_dataset.csv")

# %%
df
# Out:
#      model       month gas_price  discount  sales      TV  YouTube   Radio  \
# 0   altima  04-01-2018    $2.76    $2,169    6799    0.00     0.00    0.00
# 1   altima  05-01-2018    $2.90    $4,745   14992    0.00     0.00    3.30
# 2   altima  06-01-2018    $2.89    $4,895   19572    0.00     0.00    6.48
# 3   altima  07-01-2018    $2.85    $4,924   14876    0.00     0.00   11.62
# 4   altima  08-01-2018    $2.84    $5,026   14656    0.00     0.00   32.46
# 5   altima  09-01-2018    $2.84    $4,794   11858    0.00     0.00    6.10
# 6   altima  10-01-2018    $2.86    $4,461    8361  131.93    30.37    4.96
# 7   altima  11-01-2018    $2.65    $3,737    7434  329.16   142.37   41.71
# 8   altima  12-01-2018    $2.37    $3,028    8425  379.19   304.02  220.82
# 9   altima  01-01-2019    $2.25    $3,312    8100    1.35    26.15  115.37
# 10  altima  02-01-2019    $2.31    $3,293    9533    1.76    67.10  146.51
# ...

# %%
df.shape
# Out:
# (36, 9)

# %%
df.head()
# Out:
#     model       month gas_price  discount  sales   TV  YouTube  Radio  Print
# 0  altima  04-01-2018    $2.76    $2,169    6799  0.0      0.0   0.00   1.40
# 1  altima  05-01-2018    $2.90    $4,745   14992  0.0      0.0   3.30   0.22
# 2  altima  06-01-2018    $2.89    $4,895   19572  0.0      0.0   6.48   0.15
# 3  altima  07-01-2018    $2.85    $4,924   14876  0.0      0.0  11.62   0.68
# 4  altima  08-01-2018    $2.84    $5,026   14656  0.0      0.0  32.46   1.63

# %%
df.tail()
# Out:
#      model       month gas_price  discount  sales     TV  YouTube   Radio  \
# 31  altima  11-01-2020    $2.11    $3,317    7642  51.69    55.10   95.94
# 32  altima  12-01-2020    $2.20    $3,131    8971   0.00     6.14  118.66
# 33  altima  01-01-2021    $2.33    $3,260    4820   0.00     0.00    6.81
# 34  altima  02-01-2021    $2.50    $3,238    5090   0.00     0.00   76.92
# 35  altima  03-01-2021    $2.81    $3,223    8384   0.00     0.00  100.97
#
#     Print
# 31   0.26
# 32   0.14
# 33   0.28
# 34   0.32
# 35   0.42

# %%
df.columns
# Out:
# Index(['model', 'month', 'gas_price', 'discount', 'sales', 'TV', 'YouTube',
#        'Radio', 'Print'],
#       dtype='object')

# %%
df.dtypes
# Out:
# model         object
# month         object
# gas_price     object
# discount      object
# sales          int64
# TV           float64
# YouTube      float64
# Radio        float64
# Print        float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      36 non-null     object
#  1   month      36 non-null     object
#  2   gas_price  36 non-null     object
#  3   discount   36 non-null     object
#  4   sales      36 non-null     int64
#  5   TV         36 non-null     float64
#  6   YouTube    36 non-null     float64
#  7   Radio      36 non-null     float64
#  8   Print      36 non-null     float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 2.7+ KB

# %%
df.isnull().sum()
# Out:
# model        0
# month        0
# gas_price    0
# discount     0
# sales        0
# TV           0
# YouTube      0
# Radio        0
# Print        0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#               sales          TV     YouTube       Radio      Print
# count     36.000000   36.000000   36.000000   36.000000  36.000000
# mean    9401.722222   36.279722   40.619167   82.869722   0.940556
# std     3201.379476   86.346870   77.807640   88.830521   1.192773
# min     3837.000000    0.000000    0.000000    0.000000   0.000000
# 25%     7590.000000    0.000000    0.000000    6.727500   0.187500
# 50%     8562.000000    0.000000    0.000000   38.560000   0.370000
# 75%    10565.250000   25.082500   39.402500  147.027500   1.302500
# max    19572.000000  379.190000  304.020000  295.440000   4.610000

# %%
df['sales'].describe()
# Out:
# count       36.000000
# mean      9401.722222
# std       3201.379476
# min       3837.000000
# 25%       7590.000000
# 50%       8562.000000
# 75%      10565.250000
# max      19572.000000
# Name: sales, dtype: float64

# %%
df.head()
# Out:
#     model       month gas_price  discount  sales   TV  YouTube  Radio  Print
# 0  altima  04-01-2018    $2.76    $2,169    6799  0.0      0.0   0.00   1.40
# 1  altima  05-01-2018    $2.90    $4,745   14992  0.0      0.0   3.30   0.22
# 2  altima  06-01-2018    $2.89    $4,895   19572  0.0      0.0   6.48   0.15
# 3  altima  07-01-2018    $2.85    $4,924   14876  0.0      0.0  11.62   0.68
# 4  altima  08-01-2018    $2.84    $5,026   14656  0.0      0.0  32.46   1.63

# %%
df['gas_price'] = df['gas_price'].str.replace('$', '', regex=False).astype(float)

# %%
df['discount'] = df['discount'].str.replace('$', '', regex=False)

# %%
df.head()
# Out:
#     model       month  gas_price discount  sales   TV  YouTube  Radio  Print
# 0  altima  04-01-2018       2.76   2,169    6799  0.0      0.0   0.00   1.40
# 1  altima  05-01-2018       2.90   4,745   14992  0.0      0.0   3.30   0.22
# 2  altima  06-01-2018       2.89   4,895   19572  0.0      0.0   6.48   0.15
# 3  altima  07-01-2018       2.85   4,924   14876  0.0      0.0  11.62   0.68
# 4  altima  08-01-2018       2.84   5,026   14656  0.0      0.0  32.46   1.63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      36 non-null     object
#  1   month      36 non-null     object
#  2   gas_price  36 non-null     float64
#  3   discount   36 non-null     object
#  4   sales      36 non-null     int64
#  5   TV         36 non-null     float64
#  6   YouTube    36 non-null     float64
#  7   Radio      36 non-null     float64
#  8   Print      36 non-null     float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
df['discount'] = df['discount'].str.replace(',', '').str.strip()

# %%
df['discount'] = df['discount'].astype(int)

# %%
df.dtypes
# Out:
# model         object
# month         object
# gas_price    float64
# discount       int32
# sales          int64
# TV           float64
# YouTube      float64
# Radio        float64
# Print        float64
# dtype: object

# %%
df['month'] = pd.to_datetime(df['month'])

# %%
df['Day'] = df['month'].dt.day
df['Month'] = df['month'].dt.month 
df['Year'] = df['month'].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      36 non-null     object
#  1   month      36 non-null     datetime64[ns]
#  2   gas_price  36 non-null     float64
#  3   discount   36 non-null     int32
#  4   sales      36 non-null     int64
#  5   TV         36 non-null     float64
#  6   YouTube    36 non-null     float64
#  7   Radio      36 non-null     float64
#  8   Print      36 non-null     float64
#  9   Day        36 non-null     int64
#  10  Month      36 non-null     int64
#  11  Year       36 non-null     int64
# dtypes: datetime64[ns](1), float64(5), int32(1), int64(4), object(1)
# memory usage: 3.4+ KB

# %% [markdown]
# 2. Which is your dependent variable?

# %% [markdown]
#      In this Modeling dataset, Sales is my dependent variables
#     and all others variables are independent variables.

# %% [markdown]
# 3. Which variables are significant in the model?

# %%
df.head()
# Out:
#     model      month  gas_price  discount  sales   TV  YouTube  Radio  Print  \
# 0  altima 2018-04-01       2.76      2169   6799  0.0      0.0   0.00   1.40
# 1  altima 2018-05-01       2.90      4745  14992  0.0      0.0   3.30   0.22
# 2  altima 2018-06-01       2.89      4895  19572  0.0      0.0   6.48   0.15
# 3  altima 2018-07-01       2.85      4924  14876  0.0      0.0  11.62   0.68
# 4  altima 2018-08-01       2.84      5026  14656  0.0      0.0  32.46   1.63
#
#    Day  Month  Year
# 0    1      4  2018
# 1    1      5  2018
# 2    1      6  2018
# 3    1      7  2018
# 4    1      8  2018

# %%
df.drop('month', axis =1, inplace = True)

# %%
df['model'].value_counts()
# Out:
# altima    36
# Name: model, dtype: int64

# %%
df['Day'].value_counts()
# Out:
# 1    36
# Name: Day, dtype: int64

# %% [markdown]
# Since 'Model' column has same values for all rows,
# it will not make any impact in predicting the output, so we will drop the model column

# %%
df.drop('model', axis =1, inplace = True)

# %%
df.drop('Day', axis =1, inplace = True)

# %%
df.head()
# Out:
#    gas_price  discount  sales   TV  YouTube  Radio  Print  Month  Year
# 0       2.76      2169   6799  0.0      0.0   0.00   1.40      4  2018
# 1       2.90      4745  14992  0.0      0.0   3.30   0.22      5  2018
# 2       2.89      4895  19572  0.0      0.0   6.48   0.15      6  2018
# 3       2.85      4924  14876  0.0      0.0  11.62   0.68      7  2018
# 4       2.84      5026  14656  0.0      0.0  32.46   1.63      8  2018

# %%
df.corr()
# Out:
#            gas_price  discount     sales        TV   YouTube     Radio  \
# gas_price   1.000000  0.439313  0.602599 -0.001251 -0.109717  0.059895
# discount    0.439313  1.000000  0.688287 -0.045200 -0.119993 -0.309972
# sales       0.602599  0.688287  1.000000 -0.101005 -0.019421 -0.045429
# TV         -0.001251 -0.045200 -0.101005  1.000000  0.725431  0.110964
# YouTube    -0.109717 -0.119993 -0.019421  0.725431  1.000000  0.272932
# Radio       0.059895 -0.309972 -0.045429  0.110964  0.272932  1.000000
# Print       0.335222  0.234431 -0.035509  0.419606  0.309909  0.151132
# Month       0.037186  0.216420  0.166056  0.522212  0.468152  0.079877
# Year       -0.611043 -0.505533 -0.601917 -0.325916 -0.194867  0.044294
#
#               Print     Month      Year
# gas_price  0.335222  0.037186 -0.611043
# discount   0.234431  0.216420 -0.505533
# sales     -0.035509  0.166056 -0.601917
# TV         0.419606  0.522212 -0.325916
# YouTube    0.309909  0.468152 -0.194867
# ...

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(),cmap='Reds',annot=True)
# Out:
# <Axes: >

# %%
x = df.drop('sales', axis =1)
y = df['sales']

# %%
x.head()
# Out:
#    gas_price  discount   TV  YouTube  Radio  Print  Month  Year
# 0       2.76      2169  0.0      0.0   0.00   1.40      4  2018
# 1       2.90      4745  0.0      0.0   3.30   0.22      5  2018
# 2       2.89      4895  0.0      0.0   6.48   0.15      6  2018
# 3       2.85      4924  0.0      0.0  11.62   0.68      7  2018
# 4       2.84      5026  0.0      0.0  32.46   1.63      8  2018

# %%
y.head()
# Out:
# 0     6799
# 1    14992
# 2    19572
# 3    14876
# 4    14656
# Name: sales, dtype: int64

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
vif["features"] = x.columns

vif
# Out:
#    VIF values   features
# 0  101.429123  gas_price
# 1   55.827877   discount
# 2    3.127688         TV
# 3    3.122473    YouTube
# 4    2.526777      Radio
# 5    2.423815      Print
# 6    7.173779      Month
# 7   89.655996       Year

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
maxAcc = 0
maxRS= 0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    LR = LinearRegression()
    LR.fit(x_train,y_train)
    pred = LR.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc>maxAcc:
        maxAcc = acc
        maxRS = i
        
print("The best r2_score is ", maxAcc, "at random state ", maxRS)
# Out:
# The best r2_score is  0.8496530376057461 at random state  87

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=87)

# %%
#checking accuracy for LinearRegression
LR = LinearRegression()
LR.fit(x_train,y_train)
predLR = LR.predict(x_test)
pred_train_LR = LR.predict(x_train)
print('R2_score : ', r2_score(y_test,predLR)*100)
print('R2_score on training data : ', r2_score(y_train,pred_train_LR)*100)
print('Mean Absolute Error : ', mean_absolute_error(y_test,predLR))
print('Mean Squared Error : ', mean_squared_error(y_test,predLR))
print('Root Mean Squared Error : ', np.sqrt(mean_squared_error(y_test,predLR)))
# Out:
# R2_score :  84.96530376057461
# R2_score on training data :  77.21708278596593
# Mean Absolute Error :  1219.5058765782635
# Mean Squared Error :  2299068.937535346
# Root Mean Squared Error :  1516.2680955343437
